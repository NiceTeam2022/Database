# %% [markdown]
# ## Documentation

# %% [markdown]
# ### Emotion类
# 属性data中存有情感词典

# %%
from Emotions import Emotion

Data = Emotion()
Data.data
# Out:
#        word    tag  number  serial sentiment  intensity  polarity  \
# 0        脏乱    adj       1       1        NN          7         2
# 1        糟报    adj       1       1        NN          5         2
# 2        早衰    adj       1       1        NE          5         2
# 3        责备   verb       1       1        NN          5         2
# 4        贼眼   noun       1       1        NN          5         2
# ...     ...    ...     ...     ...       ...        ...       ...
# 27461    增生   verb       1       1        PA          7         2
# 27462  正兒巴经  idiom       2       2        PH          5         1
# 27463  智藏瘝在  idiom       1       1        NI          7         2
# 27464    重点   noun       1       1        NI          7         0
# 27465    烛花   noun       1       1        PB          5         1
#
#       subsentiment  subintensity  subpolarity
# 0             None           NaN          NaN
# 1             None           NaN          NaN
# ...

# %% [markdown]
# ### Emoji类

# %% [markdown]
# 使用情感名称和强度初始一个Emoji类，属性picture中存有图片的路径

# %%
from Emoji import Emoji
emoji = Emoji("怒",set_intensity=1)
print(emoji.picture)
# Out:
# ./rsc/emoji/怒-5.png
